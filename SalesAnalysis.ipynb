# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    '/content/sales_data.csv',
    parse_dates= ['Date']
    )

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# ...

# %%
sales['Customer_Age'].mean()
# Out:
# 35.93515435463751

# %%
sales.mean()
# Out:
# <ipython-input-6-91335213504a>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sales.mean()
# <ipython-input-6-91335213504a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales.mean()
# Day                 15.650981
# Year              2014.384782
# Customer_Age        35.935154
# Order_Quantity      12.045702
# Unit_Cost          257.145279
# Unit_Price         438.685830
# Profit             284.841176
# Cost               464.559071
# Revenue            749.402839
# dtype: float64

# %%
sales.tail()
# Out:
#              Date  Day     Month  Year  Customer_Age       Age_Group  \
# 101806 2013-12-28   28  December  2013            43  Adults (35-64)
# 101807 2013-12-28   28  December  2013            43  Adults (35-64)
# 101808 2015-12-28   28  December  2015            43  Adults (35-64)
# 101809 2015-12-28   28  December  2015            43  Adults (35-64)
# 101810 2014-07-08    8      July  2014            44  Adults (35-64)
#
#        Customer_Gender  Country    State Product_Category     Sub_Category  \
# 101806               F  Germany  Hamburg      Accessories  Tires and Tubes
# 101807               F  Germany  Hamburg      Accessories  Tires and Tubes
# 101808               F  Germany  Hamburg      Accessories  Tires and Tubes
# 101809               F  Germany  Hamburg      Accessories  Tires and Tubes
# 101810               M   France  Moselle      Accessories  Tires and Tubes
#
#                     Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101811 entries, 0 to 101810
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              101811 non-null  datetime64[ns]
#  1   Day               101811 non-null  int64
#  2   Month             101811 non-null  object
#  3   Year              101811 non-null  int64
#  4   Customer_Age      101811 non-null  int64
#  5   Age_Group         101811 non-null  object
#  6   Customer_Gender   101811 non-null  object
#  7   Country           101811 non-null  object
#  8   State             101811 non-null  object
#  9   Product_Category  101811 non-null  object
#  10  Sub_Category      101811 non-null  object
#  11  Product           101811 non-null  object
#  12  Order_Quantity    101811 non-null  int64
#  13  Unit_Cost         101811 non-null  int64
#  14  Unit_Price        101811 non-null  int64
#  15  Profit            101811 non-null  int64
# ...

# %%
sales['Age_Group'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 101811 entries, 0 to 101810
# Series name: Age_Group
# Non-Null Count   Dtype
# --------------   -----
# 101811 non-null  object
# dtypes: object(1)
# memory usage: 795.5+ KB

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  101811.000000  101811.000000  101811.000000   101811.000000
# mean       15.650981    2014.384782      35.935154       12.045702
# std         8.784580       1.287413      11.010767        9.534223
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       11.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  101811.000000  101811.000000  101811.000000  101810.000000
# mean      257.145279     438.685830     284.841176     464.559071
# std       546.794996     922.060625     455.882600     874.472344
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
sales['Customer_Age'].max()
# Out:
# 87

# %%
sales['Customer_Age'].std()
# Out:
# 11.010766975223248

# %%
sales['Customer_Age'].25%()
# Out:
#   File "<ipython-input-17-6edc5385c33c>", line 1
#     sales['Customer_Age'].25%()
#                          ^
# SyntaxError: invalid syntax

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(12,4))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(20,10))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].min()
# Out:
# 17

# %%
sales['Customer_Age'].plot(kind='box', vert= False, figsize=(16,8))
# Out:
# <Axes: >

# %%
sales['Order_Quantity'].mean()
# Out:
# 12.045702330789403

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(20,10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=26, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(16,6))
# Out:
# <Axes: >

# %%
sales['Order_Quantity'].plot(kind='hist', bins=22, figsize=(16,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=24, figsize=(16,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Revenue'].sum()
# Out:
# 76296703.0

# %%
sales['Year'].value_counts()
# Out:
# 2014    26281
# 2016    26280
# 2013    21948
# 2015    21948
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='Year'>

# %%
sales['Month'].value_counts()
# Out:
# June         10240
# May           9954
# December      9918
# April         9188
# March         8802
# January       8428
# February      8148
# October       7838
# November      7798
# August        7416
# September     7398
# July          6683
# Name: Month, dtype: int64

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(16,8))
# Out:
# <Axes: >

# %%
sales['Country'].value_counts().head(1)
# Out:
# United States    34564
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# United States     34564
# Australia         21936
# Canada            13380
# United Kingdom    12218
# France             9939
# Germany            9774
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(16,8))
# Out:
# <Axes: >

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales['Product'].value_counts().head(20)
# Out:
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches         8750
# Mountain Tire Tube          6344
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
# Sport-100 Helmet, Black     4152
# Fender Set - Mountain       4032
# Sport-100 Helmet, Blue      3788
# Road Tire Tube              2926
# Road Bottle Cage            2640
# Mountain Bottle Cage        2444
# Touring Tire Tube           1942
# Bike Wash - Dissolver       1804
# HL Mountain Tire            1786
# ML Mountain Tire            1376
# Hydration Pack - 70 oz.     1332
# Mountain-200 Black, 38      1208
# Mountain-200 Silver, 38     1106
# ML Road Tire                1084
# Mountain-200 Silver, 42     1054
# Name: Product, dtype: int64

# %%
sales['Product'].value_counts().head(20).plot(kind='bar', figsize=(16,8))
# Out:
# <Axes: >

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>
